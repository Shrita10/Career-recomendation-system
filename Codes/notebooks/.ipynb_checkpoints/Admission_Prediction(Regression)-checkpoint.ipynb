# %%
import pandas as pd
df1 = pd.read_csv('C:\\Users\\Shrita\\Downloads\\ongoing_projects\\Admission\\ad_pr.csv')
df1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
df1.shape
# Out:
# (500, 9)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df1.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df1.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000        500.00000
# mean     3.48400    8.576440    0.560000          0.72174
# std      0.92545    0.604813    0.496884          0.14114
# min      1.00000    6.800000    0.000000          0.34000
# ...

# %%
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
import missingno as msno
msno.bar(df1)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.heatmap(df1.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
labels = ['Yes', 'No']
sizes1 = [df1['Research'].value_counts()[0],df1['Research'].value_counts()[1]]   
fig1 = plt.figure(figsize=(20,7))

ax1=fig1.add_subplot(121)
ax1.pie(sizes1, labels=labels, autopct='%1.1f%%', shadow=True , colors = ['rebeccapurple','slategrey'])
ax1.set_title('Percentage of research students',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Percentage of research students')

# %%
labels = ['3','2','4','5','1']
sizes1 = [df1['University Rating'].value_counts()[3], df1['University Rating'].value_counts()[2],
           df1['University Rating'].value_counts()[4],
         df1['University Rating'].value_counts()[5],
         df1['University Rating'].value_counts()[1]
        ]
fig1 = plt.figure(figsize=(20,7))

ax1=fig1.add_subplot(121)
ax1.pie(sizes1, labels=labels, autopct='%1.1f%%', shadow=True , colors = ['#003f5c', '#ffa600', '#bc5090','indianred','royalblue'])
ax1.set_title('Percentage of universities and their ratings',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Percentage of universities and their ratings')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.lmplot(data=df1,
           x="GRE Score",
           y="TOEFL Score")
plt.title('How are Gre and Toefl Scores related', fontsize = 18)
# Create a regression plot using hue

# %%
sns.lmplot(data=df1,
           x="SOP",
           y="LOR ")
plt.title('Are SOP and LOR Scores related?', fontsize = 18)

# %%
sns.kdeplot(df1.loc[df1['University Rating'] == 5, 'GRE Score'], label='4', shade = True)
sns.kdeplot(df1.loc[df1['University Rating'] == 1, 'GRE Score'], label='1', shade = True)
plt.title('Do good universities need good GRE Scores', fontsize = 20)
plt.show()

# %%
sns.kdeplot(df1.loc[df1['University Rating'] == 5, 'TOEFL Score'], label='4', shade = True)
sns.kdeplot(df1.loc[df1['University Rating'] == 1, 'TOEFL Score'], label='1', shade = True)
plt.title('Do good universities need good TOEFL Scores', fontsize = 20)
plt.show()

# %%
sns.kdeplot(df1.loc[df1['CGPA'] == 9.23, 'Chance of Admit'], label='4', shade = True)
sns.kdeplot(df1.loc[df1['CGPA'] == 7.65, 'Chance of Admit'], label='1', shade = True)
plt.title('Do higher CGPA increase the rate of chances', fontsize = 20)
plt.show()

# %%
f= plt.figure(figsize=(17,6))

ax1=f.add_subplot(121)
sns.countplot(df1['Research'], hue = df1['Chance of Admit'])
plt.title('does research increase the chances of admission', fontsize = 17)
ax1.get_legend().remove()

plt.show()

# %%
df1.columns
df1 = df1.drop('Serial No.',axis = 1)

# %%
X10 = df1.drop(['Chance of Admit'], axis=1)
y10 = df1['Chance of Admit']

# %%
from sklearn.model_selection import train_test_split
X_train10, X_test10, y_train10, y_test10 = train_test_split(X10, y10, test_size = 0.2 , random_state = 50)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train10, y_train10)

# %%
y_pred10 = regressor.predict(X_test10)

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
lr_r2 = r2_score(y_test10, y_pred10)
lr_mse = mean_squared_error(y_test10, y_pred10)
lr_rmse = np.sqrt(lr_mse)
print('SVR R2 Score: {0} \nSVR MSE: {1}, \nSVR RMSE:{2}'.format(lr_r2, lr_mse, lr_rmse))

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 500, random_state = 0)
regressor.fit(X_train10, y_train10)

# %%
y_pred10 = regressor.predict(X_test10)

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
lr_r2 = r2_score(y_test10, y_pred10)
lr_mse = mean_squared_error(y_test10, y_pred10)
lr_rmse = np.sqrt(lr_mse)
print('Random forest R2 Score: {0} \nRandom Forest MSE: {1}, \nRandom Forest RMSE:{2}'.format(lr_r2, lr_mse, lr_rmse))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (9,7))
plt.scatter(y_test10, y_pred10)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.title('Random Forest Regression', size = 15, weight = 'bold')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lin_reg10 = LinearRegression()
lin_reg10.fit(X_train10, y_train10)

# %%
y_pred10 = lin_reg10.predict(X_test10)

# %%
pd.DataFrame({"Actual": y_test10, "Predict": y_pred10})

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
lr_r2 = r2_score(y_test10, y_pred10)
lr_mse = mean_squared_error(y_test10, y_pred10)
lr_rmse = np.sqrt(lr_mse)
print('Linear Regression R2 Score: {0} \nLinear Regression MSE: {1}, \nLinear Regression RMSE:{2}'.format(lr_r2, lr_mse, lr_rmse))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (9,7))
plt.scatter(y_test10, y_pred10)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.title('Linear Regression', size = 15, weight = 'bold')
plt.show()

# %%
pop = [[338,112,5,5,5,9.5,1]]        #STUDENT WITH GOOD GRADES
y_pred101 = lin_reg10.predict(pop)
y_pred101

# %%
pop = [[222,86,2,2,2,4.5,0]]           #STUDENT WITH BAD GRADES
y_pred101 = lin_reg10.predict(pop)
y_pred101

# %%
pop = [[222,86,2,2,2,7.5,0]]            #STUDENT WITH AVERAGE GRADES
y_pred101 = lin_reg10.predict(pop)
y_pred101
